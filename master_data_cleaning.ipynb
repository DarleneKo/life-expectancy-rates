# %% [markdown]
# LIFE EXPECTANCY:  DATA EXPLORATION & CLEANUP
#
# Note - This is the MASTER Jupyter Notebook to merge all branches together.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file = "../life-expectancy-rates/cleaned_data_output.csv"
df = pd.read_csv(file)

# %%
df1 = df.drop(columns='Unnamed: 0').rename(columns = {"Diphtheria ": "Diphtheria"})
df1
# Out:
#           Country  Year      Status  Population  Life Expectancy  \
# 0     Afghanistan  2015  Developing  33736494.0             65.0
# 1     Afghanistan  2014  Developing    327582.0             59.9
# 2     Afghanistan  2013  Developing  31731688.0             59.9
# 3     Afghanistan  2012  Developing   3696958.0             59.5
# 4     Afghanistan  2011  Developing   2978599.0             59.2
# ...           ...   ...         ...         ...              ...
# 1644     Zimbabwe  2004  Developing  12777511.0             44.3
# 1645     Zimbabwe  2003  Developing  12633897.0             44.5
# 1646     Zimbabwe  2002  Developing    125525.0             44.8
# 1647     Zimbabwe  2001  Developing  12366165.0             45.3
# 1648     Zimbabwe  2000  Developing  12222251.0             46.0
#
#       Adult Mortality  Under-Five Deaths  Infant Deaths  HIV/AIDS  Diphtheria  \
# 0               263.0                 83             62       0.1        65.0
# 1               271.0                 86             64       0.1        62.0
# 2               268.0                 89             66       0.1        64.0
# 3               272.0                 93             69       0.1        67.0
# 4               275.0                 97             71       0.1        68.0
# ...               ...                ...            ...       ...         ...
# 1644            723.0                 42             27      33.6        65.0
# 1645            715.0                 41             26      36.7        68.0
# 1646             73.0                 40             25      39.8        71.0
# 1647            686.0                 39             25      42.1        75.0
# 1648            665.0                 39             24      43.5        78.0
#
#       ...  Polio  Thinness 5-9 years  Thinness 1-19 years  Alcohol   BMI  \
# 0     ...    6.0                17.3                 17.2     0.01  19.1
# 1     ...   58.0                17.5                 17.5     0.01  18.6
# 2     ...   62.0                17.7                 17.7     0.01  18.1
# 3     ...   67.0                18.0                 17.9     0.01  17.6
# 4     ...   68.0                18.2                 18.2     0.01  17.2
# ...   ...    ...                 ...                  ...      ...   ...
# 1644  ...   67.0                 9.4                  9.4     4.36  27.1
# 1645  ...    7.0                 9.9                  9.8     4.06  26.7
# 1646  ...   73.0                 1.3                  1.2     4.43  26.3
# 1647  ...   76.0                 1.7                  1.6     1.72  25.9
# 1648  ...   78.0                11.2                 11.0     1.68  25.5
#
#              GDP  Percentage Expenditure  Total Expenditure  \
# 0     584.259210               71.279624               8.16
# 1     612.696514               73.523582               8.18
# 2     631.744976               73.219243               8.13
# 3     669.959000               78.184215               8.52
# 4      63.537231                7.097109               7.87
# ...          ...                     ...                ...
# 1644  454.366654                0.000000               7.13
# 1645  453.351155                0.000000               6.52
# 1646   57.348340                0.000000               6.53
# 1647  548.587312                0.000000               6.16
# 1648  547.358879                0.000000               7.10
#
#       Income Composition of Resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 1644                            0.407        9.2
# 1645                            0.418        9.5
# 1646                            0.427       10.0
# 1647                            0.427        9.8
# 1648                            0.434        9.8
#
# [1649 rows x 22 columns]

# %% [markdown]
# ### Creating boxplots and histograms to analyze potential outliers:

# %%
hiv = df1['HIV/AIDS']
diphtheria = df1['Diphtheria']
hepatitisB = df1['Hepatitis B']
measles = df1['Measles']
polio = df1['Polio']

fig1, ax1 = plt.subplots()
ax1.boxplot([hiv, diphtheria, hepatitisB, polio])
plt.xticks([1, 2, 3, 4, 5], ['HIV/AIDS', 'Diphtheria', 'Hepatitis B', 'Polio'])
plt.show()

# %%
#Measles is separate because it highly skews the image of the boxplots above, check the y-axes
fig1, ax1 = plt.subplots()
ax1.boxplot(measles)
plt.xticks([1], 'Measles')
plt.show()
