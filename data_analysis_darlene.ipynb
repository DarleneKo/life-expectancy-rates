# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as stats
from scipy.stats import linregress
from matplotlib.dates import DateFormatter

# Read and display the Cleaned Data Output CSV File with Pandas
file = "../Desktop/cleaned_data_output.csv"
df = pd.read_csv(file, encoding="ISO-8859-1")
del df ["Unnamed: 0"]
df
# Out:
#           Country  Year      Status  Population  Life Expectancy  \
# 0     Afghanistan  2015  Developing  33736494.0             65.0
# 1     Afghanistan  2014  Developing    327582.0             59.9
# 2     Afghanistan  2013  Developing  31731688.0             59.9
# 3     Afghanistan  2012  Developing   3696958.0             59.5
# 4     Afghanistan  2011  Developing   2978599.0             59.2
# ...           ...   ...         ...         ...              ...
# 1644     Zimbabwe  2004  Developing  12777511.0             44.3
# 1645     Zimbabwe  2003  Developing  12633897.0             44.5
# 1646     Zimbabwe  2002  Developing    125525.0             44.8
# 1647     Zimbabwe  2001  Developing  12366165.0             45.3
# 1648     Zimbabwe  2000  Developing  12222251.0             46.0
#
#       Adult Mortality  Under-Five Deaths  Infant Deaths  HIV/AIDS  \
# 0               263.0                 83             62       0.1
# ...

# %%
df.columns

# %%
# Extract the columns to analyze immuninization factors:

immunization_factors = df[["Country", "Year", "Status", "Life Expectancy", "Diphtheria", "Hepatitis B", "Measles", "Polio"]]
immunization_factors.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ddf23eee86ac> in <module>
#       1 # Extract the columns to analyze immuninization factors:
#       2
# ----> 3 immunization_factors = df[["Country", "Year", "Status", "Life Expectancy", "Diphtheria", "Hepatitis B", "Measles", "Polio"]]
#       4 immunization_factors.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...
